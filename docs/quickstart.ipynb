# %% [markdown]
# # VECM Quickstart Tutorial
#
# Notebook ini menunjukkan cara menjalankan profile strategy sederhana dan membaca output daily signal.

# %% [markdown]
# ## 1. Install dependencies
#
# Jalankan perintah di terminal (bukan di notebook) untuk install dependency:
#
# ```bash
# pip install -r requirements.txt -r requirements-dev.txt
# ```

# %% [markdown]
# ## 2. Jalankan easy_run profile
#
# Contoh menjalankan profile `beginner` untuk pair sederhana:

# %%
# !python -m vecm_project.easy_run --profile beginner --pair "BBCA.JK,BBRI.JK" --dry-run

# %% [markdown]
# Hapus `--dry-run` jika ingin menjalankan playbook penuh.

# %% [markdown]
# ## 3. Generate daily signal
#
# Jalankan daily signal dan lihat output JSON/CSV:

# %%
# !python -m vecm_project.scripts.daily_signal

# %%
# !ls -la vecm_project/outputs/daily | tail -n 5
